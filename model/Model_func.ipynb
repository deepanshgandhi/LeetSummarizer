# %%
# !pip install mlflow transformers accelerate datasets bitsandbytes einops wandb torch peft
# !pip install git+https://github.com/huggingface/peft.git
# !pip install trl
# !pip install --ignore-installed blinker
# !pip install apache-airflow
# Out:
# Requirement already satisfied: mlflow in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (2.12.2)
# Requirement already satisfied: transformers in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (4.27.2)
# Requirement already satisfied: accelerate in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (0.30.0)
# Requirement already satisfied: datasets in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (2.12.0)
# Collecting bitsandbytes
#   Obtaining dependency information for bitsandbytes from https://files.pythonhosted.org/packages/9b/63/489ef9cd7a33c1f08f1b2be51d1b511883c5e34591aaa9873b30021cd679/bitsandbytes-0.42.0-py3-none-any.whl.metadata
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting einops
#   Obtaining dependency information for einops from https://files.pythonhosted.org/packages/44/5a/f0b9ad6c0a9017e62d4735daaeb11ba3b6c009d69a26141b258cd37b5588/einops-0.8.0-py3-none-any.whl.metadata
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting wandb
#   Obtaining dependency information for wandb from https://files.pythonhosted.org/packages/28/a4/5372a595a4e8dcbafb3e7bef58ec494979a92d6ed2d722e5f3a4b9a764b5/wandb-0.17.0-py3-none-macosx_11_0_arm64.whl.metadata
#   Downloading wandb-0.17.0-py3-none-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: Flask<4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (8.0.4)
# Requirement already satisfied: cloudpickle<4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: entrypoints<1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (3.1.43)
# Requirement already satisfied: graphene<4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (3.7.1)
# Requirement already satisfied: numpy<2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (1.24.3)
# Requirement already satisfied: packaging<25 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (23.0)
# Requirement already satisfied: pandas<3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (1.5.3)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (4.21.12)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (11.0.0)
# Requirement already satisfied: pytz<2025 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (2022.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (6.0)
# Requirement already satisfied: querystring-parser<2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (2.28.1)
# Requirement already satisfied: scikit-learn<2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: scipy<2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (1.10.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: gunicorn<23 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: filelock in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: psutil in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: xxhash in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: responses<0.19 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets) (0.13.3)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Obtaining dependency information for docker-pycreds>=0.4.0 from https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: platformdirs in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from wandb) (3.10.0)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Obtaining dependency information for sentry-sdk>=1.0.0 from https://files.pythonhosted.org/packages/25/18/9783ccc5faddc0edef492046a00164e3c2e698ef5302c85d805aa644e017/sentry_sdk-2.3.1-py2.py3-none-any.whl.metadata
#   Downloading sentry_sdk-2.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setproctitle in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from wandb) (68.0.0)
# Requirement already satisfied: Mako in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow) (4.7.1)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.16)
# Requirement already satisfied: six>=1.4.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from Flask<4->mlflow) (2.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from graphene<4->mlflow) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: sympy in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow) (5.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 30.8 MB/s eta 0:00:0000:0100:01
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 6.5 MB/s eta 0:00:00
# Downloading wandb-0.17.0-py3-none-macosx_11_0_arm64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 45.6 MB/s eta 0:00:00a 0:00:01
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading sentry_sdk-2.3.1-py2.py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 kB 25.8 MB/s eta 0:00:00
# Installing collected packages: sentry-sdk, einops, docker-pycreds, bitsandbytes, wandb
# Successfully installed bitsandbytes-0.42.0 docker-pycreds-0.4.0 einops-0.8.0 sentry-sdk-2.3.1 wandb-0.17.0
# Collecting git+https://github.com/huggingface/peft.git
#   Cloning https://github.com/huggingface/peft.git to /private/var/folders/vs/03bk43jj4jn9ptfvw49_hbv80000gn/T/pip-req-build-8xet_1ge
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /private/var/folders/vs/03bk43jj4jn9ptfvw49_hbv80000gn/T/pip-req-build-8xet_1ge
#   Resolved https://github.com/huggingface/peft.git to commit e7b75070c72a88f0f7926cc6872858a2c5f0090d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (23.0)
# Requirement already satisfied: psutil in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (6.0)
# Requirement already satisfied: torch>=1.13.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (2.0.1)
# Requirement already satisfied: transformers in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (4.27.2)
# Requirement already satisfied: tqdm in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (4.65.0)
# Requirement already satisfied: accelerate>=0.21.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (0.30.0)
# Requirement already satisfied: safetensors in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from peft==0.11.2.dev0) (0.4.3)
# Collecting huggingface-hub>=0.17.0 (from peft==0.11.2.dev0)
#   Obtaining dependency information for huggingface-hub>=0.17.0 from https://files.pythonhosted.org/packages/78/71/6ce4136149cb42b98599d49c39b3a39dd6858b5f9307490998c40e26a51e/huggingface_hub-0.23.2-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.23.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (2024.5.0)
# Requirement already satisfied: requests in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.17.0->peft==0.11.2.dev0) (4.7.1)
# Requirement already satisfied: sympy in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.11.2.dev0) (1.11.1)
# Requirement already satisfied: networkx in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.11.2.dev0) (3.1)
# Requirement already satisfied: jinja2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.11.2.dev0) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers->peft==0.11.2.dev0) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers->peft==0.11.2.dev0) (0.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft==0.11.2.dev0) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.2.dev0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.13.0->peft==0.11.2.dev0) (1.3.0)
# Downloading huggingface_hub-0.23.2-py3-none-any.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.7/401.7 kB 4.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: peft
#   Building wheel for peft (pyproject.toml) ... done
#   Created wheel for peft: filename=peft-0.11.2.dev0-py3-none-any.whl size=254282 sha256=494394458d21c3f39ef04105d5e2eeb9b61ec263312e6f77db772a8dc9190ce3
#   Stored in directory: /private/var/folders/vs/03bk43jj4jn9ptfvw49_hbv80000gn/T/pip-ephem-wheel-cache-ljq54gvi/wheels/42/ec/c4/eb24dac74be83ba2ed4817037a784d1c775e317cb8de69963f
# Successfully built peft
# Installing collected packages: huggingface-hub, peft
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.15.1
#     Uninstalling huggingface-hub-0.15.1:
#       Successfully uninstalled huggingface-hub-0.15.1
#   Attempting uninstall: peft
#     Found existing installation: peft 0.3.0
#     Uninstalling peft-0.3.0:
#       Successfully uninstalled peft-0.3.0
# Successfully installed huggingface-hub-0.23.2 peft-0.11.2.dev0
# Collecting trl
#   Obtaining dependency information for trl from https://files.pythonhosted.org/packages/97/7e/274ed94ab7da21db4b7cbccad2bf2ed0940082a929b1512e508351b289f5/trl-0.8.6-py3-none-any.whl.metadata
#   Downloading trl-0.8.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.4.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from trl) (2.0.1)
# Collecting transformers>=4.31.0 (from trl)
#   Obtaining dependency information for transformers>=4.31.0 from https://files.pythonhosted.org/packages/79/e1/dcba5ba74392015ceeababf3455138f5875202e66e3316d7ca223bdb7b1c/transformers-4.41.1-py3-none-any.whl.metadata
#   Downloading transformers-4.41.1-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from trl) (1.24.3)
# Requirement already satisfied: accelerate in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from trl) (0.30.0)
# Requirement already satisfied: datasets in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from trl) (2.12.0)
# Collecting tyro>=0.5.11 (from trl)
#   Obtaining dependency information for tyro>=0.5.11 from https://files.pythonhosted.org/packages/11/9d/bad5061876ee331cd2fc23f7a1fdbdb13ea2d65738fbb4e354b3ba644865/tyro-0.8.4-py3-none-any.whl.metadata
#   Downloading tyro-0.8.4-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: filelock in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.4.0->trl) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.4.0->trl) (4.7.1)
# Requirement already satisfied: sympy in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.4.0->trl) (1.11.1)
# Requirement already satisfied: networkx in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.4.0->trl) (3.1)
# Requirement already satisfied: jinja2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers>=4.31.0->trl) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers>=4.31.0->trl) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers>=4.31.0->trl) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers>=4.31.0->trl) (2022.7.9)
# Requirement already satisfied: requests in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers>=4.31.0->trl) (2.28.1)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.31.0->trl)
#   Obtaining dependency information for tokenizers<0.20,>=0.19 from https://files.pythonhosted.org/packages/90/79/d17a0f491d10817cd30f1121a07aa09c8e97a81114b116e473baf1577f09/tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers>=4.31.0->trl) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from transformers>=4.31.0->trl) (4.65.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Obtaining dependency information for docstring-parser>=0.14.1 from https://files.pythonhosted.org/packages/d5/7c/e9fcff7623954d86bdc17782036cbf715ecab1bec4847c008557affe1ca8/docstring_parser-0.16-py3-none-any.whl.metadata
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: rich>=11.1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from tyro>=0.5.11->trl) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Obtaining dependency information for shtab>=1.5.6 from https://files.pythonhosted.org/packages/e2/d1/a1d3189e7873408b9dc396aef0d7926c198b0df2aa3ddb5b539d3e89a70f/shtab-1.7.1-py3-none-any.whl.metadata
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: psutil in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from accelerate->trl) (5.9.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (11.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (0.3.6)
# Requirement already satisfied: pandas in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (1.5.3)
# Requirement already satisfied: xxhash in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (2.0.2)
# Requirement already satisfied: multiprocess in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (2024.5.0)
# Requirement already satisfied: aiohttp in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (3.9.5)
# Requirement already satisfied: responses<0.19 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from datasets->trl) (0.13.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->trl) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->trl) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->trl) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->trl) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->trl) (1.8.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.31.0->trl) (2024.2.2)
# Requirement already satisfied: six in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from responses<0.19->datasets->trl) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.4.0->trl) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from pandas->datasets->trl) (2022.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.0)
# Downloading trl-0.8.6-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading transformers-4.41.1-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 37.9 MB/s eta 0:00:0000:0100:01
# Downloading tyro-0.8.4-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 11.5 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: shtab, docstring-parser, tyro, tokenizers, transformers, trl
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.2
#     Uninstalling tokenizers-0.13.2:
#       Successfully uninstalled tokenizers-0.13.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.27.2
#     Uninstalling transformers-4.27.2:
#       Successfully uninstalled transformers-4.27.2
# Successfully installed docstring-parser-0.16 shtab-1.7.1 tokenizers-0.19.1 transformers-4.41.1 trl-0.8.6 tyro-0.8.4
# Collecting blinker
#   Obtaining dependency information for blinker from https://files.pythonhosted.org/packages/bb/2a/10164ed1f31196a2f7f3799368a821765c62851ead0e630ab52b8e14b4d0/blinker-1.8.2-py3-none-any.whl.metadata
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Installing collected packages: blinker
# Successfully installed blinker-1.8.2
# Requirement already satisfied: apache-airflow in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (2.9.1)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.13.1)
# Requirement already satisfied: argcomplete>=1.10 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.3.0)
# Requirement already satisfied: asgiref in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.8.1)
# Requirement already satisfied: attrs>=22.1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (23.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.8.2)
# Requirement already satisfied: colorlog<5.0,>=4.0.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (4.8.0)
# Requirement already satisfied: configupdater>=3.1.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.2)
# Requirement already satisfied: connexion[flask]<3.0,>=2.10.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.14.2)
# Requirement already satisfied: cron-descriptor>=1.2.24 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.4.3)
# Requirement already satisfied: croniter>=2.0.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.0.5)
# Requirement already satisfied: cryptography>=39.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (41.0.2)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.2.14)
# Requirement already satisfied: dill>=0.2.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.3.6)
# Requirement already satisfied: flask-caching>=1.5.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.3.0)
# Requirement already satisfied: flask-session<0.6,>=0.4.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.5.0)
# Requirement already satisfied: flask-wtf>=0.15 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.2.1)
# Requirement already satisfied: flask<2.3,>=2.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.2.2)
# Requirement already satisfied: fsspec>=2023.10.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2024.5.0)
# Requirement already satisfied: google-re2>=1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.1.20240501)
# Requirement already satisfied: gunicorn>=20.1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (22.0.0)
# Requirement already satisfied: httpx in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.27.0)
# Requirement already satisfied: importlib_metadata>=6.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (7.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.0.1)
# Requirement already satisfied: jinja2>=3.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.1.2)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (4.22.0)
# Requirement already satisfied: lazy-object-proxy in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.6.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.0.0)
# Requirement already satisfied: lockfile>=0.12.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.12.2)
# Requirement already satisfied: markdown-it-py>=2.1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.2.0)
# Requirement already satisfied: markupsafe>=1.1.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.1.1)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.1.1)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.3.0)
# Requirement already satisfied: methodtools>=0.4.7 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.4.7)
# Requirement already satisfied: opentelemetry-api>=1.15.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.24.0)
# Requirement already satisfied: packaging>=14.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (23.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.10.3)
# Requirement already satisfied: pendulum<4.0,>=2.1.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.0.0)
# Requirement already satisfied: pluggy>=1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.0.0)
# Requirement already satisfied: psutil>=4.2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (5.9.0)
# Requirement already satisfied: pygments>=2.0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.15.1)
# Requirement already satisfied: pyjwt>=2.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.4.0)
# Requirement already satisfied: python-daemon>=3.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.8.2)
# Requirement already satisfied: python-nvd3>=0.15.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.16.0)
# Requirement already satisfied: python-slugify>=5.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (5.0.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.28.1)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.1.4)
# Requirement already satisfied: rich-argparse>=1.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.4.0)
# Requirement already satisfied: rich>=12.4.4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (13.7.1)
# Requirement already satisfied: setproctitle>=1.1.8 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.3.3)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.36 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.4.39)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.0.2)
# Requirement already satisfied: tabulate>=0.7.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.8.10)
# Requirement already satisfied: tenacity!=8.2.0,>=6.2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (8.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.4.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.14.1)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (0.2.2)
# Requirement already satisfied: werkzeug<3,>=2.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (2.2.3)
# Requirement already satisfied: apache-airflow-providers-common-io in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.3.1)
# Requirement already satisfied: apache-airflow-providers-common-sql in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.13.0)
# Requirement already satisfied: apache-airflow-providers-fab>=1.0.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.1.0)
# Requirement already satisfied: apache-airflow-providers-ftp in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.9.0)
# Requirement already satisfied: apache-airflow-providers-http in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (4.11.0)
# Requirement already satisfied: apache-airflow-providers-imap in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.6.0)
# Requirement already satisfied: apache-airflow-providers-smtp in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (1.7.0)
# Requirement already satisfied: apache-airflow-providers-sqlite in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow) (3.8.0)
# Requirement already satisfied: Mako in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from alembic<2.0,>=1.13.1->apache-airflow) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from alembic<2.0,>=1.13.1->apache-airflow) (4.7.1)
# Requirement already satisfied: flask-appbuilder==4.4.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.4.1)
# Requirement already satisfied: flask-login>=0.6.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.6.3)
# Requirement already satisfied: apispec[yaml]<7,>=6.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (6.6.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.4.6)
# Requirement already satisfied: click<9,>=8 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (8.0.4)
# Requirement already satisfied: email-validator>=1.0.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.1.1)
# Requirement already satisfied: Flask-Babel<3,>=1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.0.0)
# Requirement already satisfied: Flask-Limiter<4,>3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.6.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.5.1)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.6.0)
# Requirement already satisfied: marshmallow<4,>=3.18.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.21.2)
# Requirement already satisfied: marshmallow-sqlalchemy<0.29.0,>=0.22.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.28.2)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.2.1)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.41.2)
# Requirement already satisfied: WTForms<4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.1.2)
# Requirement already satisfied: clickclick<21,>=1.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow) (20.10.2)
# Requirement already satisfied: PyYAML<7,>=5.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow) (6.0)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow) (0.5.1)
# Requirement already satisfied: pytz>2021.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from croniter>=2.0.2->apache-airflow) (2022.7)
# Requirement already satisfied: cffi>=1.12 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from cryptography>=39.0.0->apache-airflow) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from deprecated>=1.2.13->apache-airflow) (1.14.1)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from flask-caching>=1.5.0->apache-airflow) (0.9.0)
# Requirement already satisfied: zipp>=0.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from importlib_metadata>=6.5->apache-airflow) (3.11.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->apache-airflow) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->apache-airflow) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->apache-airflow) (0.18.1)
# Requirement already satisfied: uc-micro-py in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from linkify-it-py>=2.0.0->apache-airflow) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.1.0->apache-airflow) (0.1.0)
# Requirement already satisfied: wirerope>=0.4.7 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from methodtools>=0.4.7->apache-airflow) (0.4.7)
# Requirement already satisfied: tzdata>=2020.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from pendulum<4.0,>=2.1.2->apache-airflow) (2024.1)
# Requirement already satisfied: time-machine>=2.6.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from pendulum<4.0,>=2.1.2->apache-airflow) (2.14.1)
# Requirement already satisfied: docutils in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from python-daemon>=3.0.0->apache-airflow) (0.18.1)
# Requirement already satisfied: setuptools>=62.4.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from python-daemon>=3.0.0->apache-airflow) (68.0.0)
# Requirement already satisfied: six>=1.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.3->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->apache-airflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->apache-airflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->apache-airflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->apache-airflow) (2024.2.2)
# Requirement already satisfied: more-itertools>=9.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow-providers-common-sql->apache-airflow) (10.2.0)
# Requirement already satisfied: sqlparse>=0.4.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow-providers-common-sql->apache-airflow) (0.5.0)
# Requirement already satisfied: aiohttp>=3.9.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow-providers-http->apache-airflow) (3.9.5)
# Requirement already satisfied: requests_toolbelt in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from apache-airflow-providers-http->apache-airflow) (1.0.0)
# Requirement already satisfied: anyio in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from httpx->apache-airflow) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from httpx->apache-airflow) (1.0.5)
# Requirement already satisfied: sniffio in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from httpx->apache-airflow) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx->apache-airflow) (0.14.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.24.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp->apache-airflow) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.24.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp->apache-airflow) (1.24.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (1.63.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (1.60.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (1.24.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-proto==1.24.0->opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (4.21.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.8.1)
# Requirement already satisfied: pycparser in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=39.0.0->apache-airflow) (2.21)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from email-validator>=1.0.5->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.6.1)
# Requirement already satisfied: Babel>=2.3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.11.0)
# Requirement already satisfied: limits>=2.8 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.12.0)
# Requirement already satisfied: ordered-set<5,>4 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from opentelemetry-sdk~=1.24.0->opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow) (0.45b0)
# Requirement already satisfied: importlib-resources>=1.3 in /Users/rahulodedra/anaconda3/lib/python3.11/site-packages (from limits>=2.8->Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow) (6.1.0)

# %%
import torch
import mlflow
import mlflow.pytorch
import pandas as pd
from peft import LoraConfig, get_peft_model
from transformers import TrainingArguments
from trl import SFTTrainer
from datasets import Dataset
import warnings
from datasets import Dataset
from huggingface_hub import login
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
warnings.filterwarnings("ignore")

# %%
def install_packages():
    # !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
    # !pip install -q datasets bitsandbytes einops wandb

def login_huggingface(token):
    login(token)

def load_data(file_path):
    df = pd.read_excel(file_path)
    return df

def preprocess_data(df):
    df["question"] = (
        df["Question"]
        + "\n Code: )"
        + df["Code"]
        + "\n Plain Text: )"
    )
    custom_ds = pd.DataFrame()
    custom_ds["prompt"] = df["question"]
    dataset = Dataset.from_pandas(custom_ds)
    return dataset

def load_model_and_tokenizer(model_name):
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
    )
    model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=bnb_config, trust_remote_code=True)
    model.config.use_cache = False
    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
    tokenizer.pad_token = tokenizer.eos_token
    return model, tokenizer

def configure_peft(lora_alpha=16, lora_dropout=0.1, lora_r=64):
    peft_config = LoraConfig(
        lora_alpha=lora_alpha,
        lora_dropout=lora_dropout,
        r=lora_r,
        bias="none",
        task_type="CAUSAL_LM",
    )
    return peft_config

def create_training_arguments(output_dir="./results", per_device_train_batch_size=4, gradient_accumulation_steps=4,
                              optim="paged_adamw_32bit", save_steps=200, logging_steps=10, learning_rate=2e-4,
                              max_grad_norm=0.3, max_steps=10, warmup_ratio=0.03, lr_scheduler_type="constant"):
    training_arguments = TrainingArguments(
        output_dir=output_dir,
        per_device_train_batch_size=per_device_train_batch_size,
        gradient_accumulation_steps=gradient_accumulation_steps,
        optim=optim,
        save_steps=save_steps,
        logging_steps=logging_steps,
        learning_rate=learning_rate,
        fp16=True,
        max_grad_norm=max_grad_norm,
        max_steps=max_steps,
        warmup_ratio=warmup_ratio,
        group_by_length=True,
        lr_scheduler_type=lr_scheduler_type,
    )
    return training_arguments

def train_model(model, dataset, peft_config, tokenizer, training_arguments, max_seq_length=512):
    trainer = SFTTrainer(
        model=model,
        train_dataset=dataset,
        peft_config=peft_config,
        dataset_text_field="prompt",
        max_seq_length=max_seq_length,
        tokenizer=tokenizer,
        args=training_arguments,
    )
    for name, module in trainer.model.named_modules():
        if "norm" in name:
            module = module.to(torch.float32)
    trainer.train()
    return trainer

def save_model(trainer, output_path="outputs"):
    model_to_save = trainer.model.module if hasattr(trainer.model, 'module') else trainer.model
    model_to_save.save_pretrained(output_path)

def load_trained_model(model, output_path="outputs"):
    lora_config = LoraConfig.from_pretrained(output_path)
    model = get_peft_model(model, lora_config)
    return model

def generate_text(model, tokenizer, test_df):
    test_row = test_df.head(1)
    test_text = test_row["Prompt"].values[0] + "\n Question: )" + test_row["Question"].values[0] + "\n Code: )" + test_row["Code"].values[0] + "\n Plain Text: )"
    print(test_text)
    input_ids = tokenizer.encode(test_text, return_tensors="pt", max_length=1024, truncation=True)
    with torch.no_grad():
        output = model.generate(input_ids, max_length=400, num_return_sequences=1)
    for i, seq in enumerate(output):
        generated_text = tokenizer.decode(seq, skip_special_tokens=True)
        print(f"Generated text {i+1}: {generated_text}")

# %%
# from google.colab import files
# uploaded = files.upload()

# file_name = list(uploaded.keys())[0]
# train_file_name = '/Users/rahulodedra/Downloads/train.xlsx'
# df = pd.read_excel(train_file_name)

# %%
# test_file_name = '/Users/rahulodedra/Downloads/test.xlsx'
# df = pd.read_excel(test_file_name)

# %%
def main():
    mlflow.start_run()  # Start MLFlow run

    try:
        install_packages()
        print('1')
        login_huggingface("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")
        print('2')
        # train_df = load_data('/Users/rahulodedra/Downloads/train.xlsx')
        print('3')
        dataset = preprocess_data(df)
        print('4')
        model_name = "meta-llama/Llama-2-7b-chat-hf"
        model, tokenizer = load_model_and_tokenizer(model_name)
        print('5')
        peft_config = configure_peft()
        print('6')
        training_arguments = create_training_arguments()
        print('7')
        trainer = train_model(model, dataset, peft_config, tokenizer, training_arguments)
        save_model(trainer)
        model = load_trained_model(model)
        test_df = load_data('/Users/rahulodedra/Downloads/test.xlsx')
        generate_text(model, tokenizer, test_df)

        # Log model and parameters
        mlflow.pytorch.log_model(model, "model")
        mlflow.log_params({
            "lora_alpha": 16,
            "lora_dropout": 0.1,
            "lora_r": 64,
            "learning_rate": 2e-4,
            "max_steps": 10
        })

    finally:
        mlflow.end_run()  # End the MLFlow run

if __name__ == "__main__":
    main()
# Out:
# 1
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/rahulodedra/.cache/huggingface/token
# Login successful
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 40
#      37         mlflow.end_run()  # End the MLFlow run
#      39 if __name__ == "__main__":
# ---> 40     main()
#
# Cell In[13], line 14, in main()
#      12 print('4')
#      13 model_name = "meta-llama/Llama-2-7b-chat-hf"
# ---> 14 model, tokenizer = load_model_and_tokenizer(model_name)
#      15 print('5')
#      16 peft_config = configure_peft()
#
# Cell In[7], line 30, in load_model_and_tokenizer(model_name)
#      24 def load_model_and_tokenizer(model_name):
#      25     bnb_config = BitsAndBytesConfig(
#      26         load_in_4bit=True,
#      27         bnb_4bit_quant_type="nf4",
#      28         bnb_4bit_compute_dtype=torch.float16,
#      29     )
# ---> 30     model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=bnb_config, trust_remote_code=True)
#      31     model.config.use_cache = False
#      32     tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/modeling_utils.py:3202, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3199     hf_quantizer = None
#    3201 if hf_quantizer is not None:
# -> 3202     hf_quantizer.validate_environment(
#    3203         torch_dtype=torch_dtype, from_tf=from_tf, from_flax=from_flax, device_map=device_map
#    3204     )
#    3205     torch_dtype = hf_quantizer.update_torch_dtype(torch_dtype)
#    3206     device_map = hf_quantizer.update_device_map(device_map)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:62, in Bnb4BitHfQuantizer.validate_environment(self, *args, **kwargs)
#      60 def validate_environment(self, *args, **kwargs):
#      61     if not torch.cuda.is_available():
# ---> 62         raise RuntimeError("No GPU found. A GPU is needed for quantization.")
#      63     if not (is_accelerate_available() and is_bitsandbytes_available()):
#      64         raise ImportError(
#      65             "Using `bitsandbytes` 8-bit quantization requires Accelerate: `pip install accelerate` "
#      66             "and the latest version of bitsandbytes: `pip install -i https://pypi.org/simple/ bitsandbytes`"
#      67         )
#
# RuntimeError: No GPU found. A GPU is needed for quantization.
